# %% [markdown]
# <a href="https://colab.research.google.com/github/bikalpa977/LineDetection/blob/main/linedetection1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
image = cv2.imread("/content/drive/MyDrive/43_w.png");

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray)

# %%
kernel_size = 3
ret,thresh = cv2.threshold(gray,200,255,cv2.THRESH_BINARY)

# %%
cnts = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]

# %%
c = 0
for i in cnts:
        area = cv2.contourArea(i)
        if area > 300:
            cv2.drawContours(image, cnts, c, (0, 255, 0), 3)
        c+=1

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=7200x5400 at 0x7F79A38B6550>
